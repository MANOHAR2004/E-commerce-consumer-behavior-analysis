# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

print("Libraries loaded ✅")
# Out:
# Libraries loaded ✅

# %%
df = pd.read_csv("online_retail_cleaned_dataset.csv",
                 encoding=' unicode_escape')

# %%
print("shape:", df.shape)

print("columns:", df.columns.tolist)
# Out:
# shape: (1048575, 11)
# columns: <bound method IndexOpsMixin.tolist of Index(['InvoiceNO', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'Customer_Type', 'Order_Type',
#        'Quantity_Flage'],
#       dtype='object')>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   InvoiceNO       1048575 non-null  object
#  1   StockCode       1048575 non-null  object
#  2   Description     1044203 non-null  object
#  3   Quantity        1048575 non-null  int64
#  4   InvoiceDate     1048575 non-null  object
#  5   UnitPrice       1048575 non-null  float64
#  6   CustomerID      811893 non-null   float64
#  7   Country         1048575 non-null  object
#  8   Customer_Type   1048575 non-null  object
#  9   Order_Type      1048575 non-null  object
#  10  Quantity_Flage  1048575 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 88.0+ MB

# %%
print("Null values in each column:\n")
print(df.isnull().sum())
# Out:
# Null values in each column:
#
# InvoiceNO              0
# StockCode              0
# Description         4372
# Quantity               0
# InvoiceDate            0
# UnitPrice              0
# CustomerID        236682
# Country                0
# Customer_Type          0
# Order_Type             0
# Quantity_Flage         0
# dtype: int64

# %%
df.rename(columns={'Quantity_Flage': 'Quantity_Flag'}, inplace=True)

# %%
print("Columns after renaming:\n")
df.info()
# Out:
# Columns after renaming:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 11 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   InvoiceNO      1048575 non-null  object
#  1   StockCode      1048575 non-null  object
#  2   Description    1044203 non-null  object
#  3   Quantity       1048575 non-null  int64
#  4   InvoiceDate    1048575 non-null  object
#  5   UnitPrice      1048575 non-null  float64
#  6   CustomerID     811893 non-null   float64
#  7   Country        1048575 non-null  object
#  8   Customer_Type  1048575 non-null  object
#  9   Order_Type     1048575 non-null  object
#  10  Quantity_Flag  1048575 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 88.0+ MB

# %%
df.head(5)
# Out:
#   InvoiceNO StockCode                          Description  Quantity  \
# 0    489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1    489434    79323P                   PINK CHERRY LIGHTS        12
# 2    489434    79323W                  WHITE CHERRY LIGHTS        12
# 3    489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4    489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  UnitPrice  CustomerID         Country Customer_Type  \
# 0  2009-12-01 07:45:00       6.95     13085.0  United Kingdom    Registered
# 1  2009-12-01 07:45:00       6.75     13085.0  United Kingdom    Registered
# 2  2009-12-01 07:45:00       6.75     13085.0  United Kingdom    Registered
# 3  2009-12-01 07:45:00       2.10     13085.0  United Kingdom    Registered
# 4  2009-12-01 07:45:00       1.25     13085.0  United Kingdom    Registered
#
#   Order_Type Quantity_Flag
# 0     Normal          Sale
# 1     Normal          Sale
# 2     Normal          Sale
# 3     Normal          Sale
# 4     Normal          Sale
